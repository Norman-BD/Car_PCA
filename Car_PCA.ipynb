# %%
import pandas as pd
import plotly.express as px
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import numpy as np

# %%
data = pd.read_csv('/content/2021_MPG_data.csv')
data
# Out:
#       Model Year  ... Comb CO2 Rounded Adjusted (as shown on FE Label)
# 0           2021  ...                                              420
# 1           2021  ...                                              541
# 2           2021  ...                                              435
# 3           2021  ...                                              567
# 4           2021  ...                                              528
# ...          ...  ...                                              ...
# 1103        2021  ...                                              618
# 1104        2021  ...                                              618
# 1105        2021  ...                                              485
# 1106        2021  ...                                              394
# 1107        2021  ...                                              380
#
# [1108 rows x 60 columns]
# Warning: Total number of columns (60) exceeds max_columns (20) limiting to first (20) columns.

# %%
  numerical_columns_list = []
  categorical_columns_list = []

# %%
for i in data.columns:
        if data[i].dtype == np.dtype("float64") or data[i].dtype == np.dtype("int64"):
            numerical_columns_list.append(data[i])
        else:
            categorical_columns_list.append(data[i])

# %%
numerical_data = pd.concat(numerical_columns_list, axis=1)
numerical_data
# Out:
#       Model Year  ...  Comb CO2 Rounded Adjusted (as shown on FE Label)
# 0           2021  ...                                               420
# 1           2021  ...                                               541
# 2           2021  ...                                               435
# 3           2021  ...                                               567
# 4           2021  ...                                               528
# ...          ...  ...                                               ...
# 1103        2021  ...                                               618
# 1104        2021  ...                                               618
# 1105        2021  ...                                               485
# 1106        2021  ...                                               394
# 1107        2021  ...                                               380
#
# [1108 rows x 24 columns]
# Warning: Total number of columns (24) exceeds max_columns (20) limiting to first (20) columns.

# %%
categorical_data = pd.concat(categorical_columns_list, axis=1)
categorical_data
# Out:
#                  Mfr Name  ... Stop/Start System (Engine Management System)  Description
# 0                   Honda  ...                                                Yes
# 1            aston martin  ...                                                Yes
# 2            aston martin  ...                                                 No
# 3     Volkswagen Group of  ...                                                 No
# 4     Volkswagen Group of  ...                                                 No
# ...                   ...  ...                                                ...
# 1103               Toyota  ...                                                 No
# 1104               Toyota  ...                                                 No
# 1105  Volkswagen Group of  ...                                                Yes
# 1106                Volvo  ...                                                Yes
# 1107                Volvo  ...                                                Yes
#
# [1108 rows x 36 columns]
# Warning: Total number of columns (36) exceeds max_columns (20) limiting to first (20) columns.

# %%
numerical_data = numerical_data.apply(lambda x: x.fillna(np.mean(x)))
numerical_data
# Out:
#       Model Year  ...  Comb CO2 Rounded Adjusted (as shown on FE Label)
# 0           2021  ...                                               420
# 1           2021  ...                                               541
# 2           2021  ...                                               435
# 3           2021  ...                                               567
# 4           2021  ...                                               528
# ...          ...  ...                                               ...
# 1103        2021  ...                                               618
# 1104        2021  ...                                               618
# 1105        2021  ...                                               485
# 1106        2021  ...                                               394
# 1107        2021  ...                                               380
#
# [1108 rows x 24 columns]
# Warning: Total number of columns (24) exceeds max_columns (20) limiting to first (20) columns.

# %%
scaler = StandardScaler()

scaled_values = scaler.fit_transform(numerical_data)
scaled_values
# Out:
# array([[ 0.        , -0.81210009,  0.28071518, ..., -0.32816308,
#          0.79475551,  0.11354292],
#        [ 0.        , -0.93740291,  0.65455222, ...,  1.40841794,
#          1.04960722,  1.2946782 ],
#        [ 0.        , -0.94108829,  0.65455222, ...,  0.26677672,
#          0.25956693,  0.25996464],
#        ...,
#        [ 0.        , -0.95214442,  0.35548259, ...,  0.69288224,
#          0.83298327,  0.74803708],
#        [ 0.        , -0.76419019, -0.84079595, ..., -0.03873291,
#         -0.326592  , -0.14025475],
#        [ 0.        , -0.76050482, -0.84079595, ..., -0.22364663,
#         -0.37756235, -0.27691503]])

# %%
pca = PCA()

pca_data = pca.fit_transform(scaled_values)

pca_data = pd.DataFrame(pca_data)
pca_data
# Out:
#             0         1         2   ...            21            22   23
# 0    -1.237491 -0.797510  0.875922  ... -3.066523e-16  1.466925e-16  0.0
# 1    -4.092961 -0.934042  2.046344  ... -8.733279e-17  6.151052e-17 -0.0
# 2    -1.914111 -0.740926  1.679987  ...  6.037532e-17  7.467663e-17 -0.0
# 3    -5.430289 -0.898120  2.590674  ...  1.286573e-17  3.818389e-17 -0.0
# 4    -4.444924 -0.813888  2.564951  ...  1.308626e-16 -4.080689e-17  0.0
# ...        ...       ...       ...  ...           ...           ...  ...
# 1103 -5.820253 -0.691932  0.365004  ... -5.834386e-17  2.635787e-17 -0.0
# 1104 -5.738201 -0.486752  0.651019  ... -2.488643e-17  1.712149e-17 -0.0
# 1105 -2.526516 -1.013110 -0.547106  ... -1.966914e-17 -4.870080e-17 -0.0
# 1106  0.158082 -1.093229 -0.933547  ... -3.555664e-18  1.804171e-17  0.0
# 1107  0.574366 -1.009607 -0.982922  ... -4.069925e-17  1.028670e-17  0.0
#
# [1108 rows x 24 columns]
# Warning: Total number of columns (24) exceeds max_columns (20) limiting to first (20) columns.

# %%
new_column_names = ["PCA_" + str(i) for i in range(1, len(pca_data.columns) + 1)]

# %%
column_mapper = dict(zip(list(pca_data.columns), new_column_names))

# %%
pca_data = pca_data.rename(columns=column_mapper)
pca_data
# Out:
#          PCA_1     PCA_2     PCA_3  ...        PCA_22        PCA_23  PCA_24
# 0    -1.237491 -0.797510  0.875922  ... -3.066523e-16  1.466925e-16     0.0
# 1    -4.092961 -0.934042  2.046344  ... -8.733279e-17  6.151052e-17    -0.0
# 2    -1.914111 -0.740926  1.679987  ...  6.037532e-17  7.467663e-17    -0.0
# 3    -5.430289 -0.898120  2.590674  ...  1.286573e-17  3.818389e-17    -0.0
# 4    -4.444924 -0.813888  2.564951  ...  1.308626e-16 -4.080689e-17     0.0
# ...        ...       ...       ...  ...           ...           ...     ...
# 1103 -5.820253 -0.691932  0.365004  ... -5.834386e-17  2.635787e-17    -0.0
# 1104 -5.738201 -0.486752  0.651019  ... -2.488643e-17  1.712149e-17    -0.0
# 1105 -2.526516 -1.013110 -0.547106  ... -1.966914e-17 -4.870080e-17    -0.0
# 1106  0.158082 -1.093229 -0.933547  ... -3.555664e-18  1.804171e-17     0.0
# 1107  0.574366 -1.009607 -0.982922  ... -4.069925e-17  1.028670e-17     0.0
#
# [1108 rows x 24 columns]
# Warning: Total number of columns (24) exceeds max_columns (20) limiting to first (20) columns.

# %%
output = pd.concat([data, pca_data], axis=1) 
output
# Out:
#       Model Year             Mfr Name  ...        PCA_23 PCA_24
# 0           2021                Honda  ...  1.466925e-16    0.0
# 1           2021         aston martin  ...  6.151052e-17   -0.0
# 2           2021         aston martin  ...  7.467663e-17   -0.0
# 3           2021  Volkswagen Group of  ...  3.818389e-17   -0.0
# 4           2021  Volkswagen Group of  ... -4.080689e-17    0.0
# ...          ...                  ...  ...           ...    ...
# 1103        2021               Toyota  ...  2.635787e-17   -0.0
# 1104        2021               Toyota  ...  1.712149e-17   -0.0
# 1105        2021  Volkswagen Group of  ... -4.870080e-17   -0.0
# 1106        2021                Volvo  ...  1.804171e-17    0.0
# 1107        2021                Volvo  ...  1.028670e-17    0.0
#
# [1108 rows x 84 columns]
# Warning: Total number of columns (84) exceeds max_columns (20) limiting to first (20) columns.
